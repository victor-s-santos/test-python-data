# %% [markdown]
# # Uma versão do exercício 3 usando o ORM Sqlalchemy.

# %% [markdown]
# * ### Usando como guia:
#     `https://auth0.com/blog/sqlalchemy-orm-tutorial-for-python-developers/`

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install SQLAlchemy
# Out:
# Collecting SQLAlchemy
#   Downloading https://files.pythonhosted.org/packages/34/5c/0e1d7ad0ca52544bb12f9cb8d5cc454af45821c92160ffedd38db0a317f6/SQLAlchemy-1.3.11.tar.gz (6.0MB)
#     100% |████████████████████████████████| 6.0MB 183kB/s ta 0:00:01    35% |███████████▍                    | 2.1MB 1.4MB/s eta 0:00:03
# Installing collected packages: SQLAlchemy
#   Running setup.py install for SQLAlchemy ... done
# Successfully installed SQLAlchemy-1.3.11
# You are using pip version 9.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sqlalchemy import create_engine, Column, String, Integer, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship

Base = declarative_base()
class User(Base):
    __tablename__="Pessoas"
    id = Column('id', Integer, primary_key=True)
    username = Column('username', String, unique=True)

    
engine = create_engine('postgresql://vsantos93:swordfish@localhost:5432/teste', echo=True)

Base.metadata.create_all(bind=engine)

Session = sessionmaker(bind=engine)

session = Session()
user = User()
user.id = 0
session.add(user)
session.commit()
user.username = 'victor'

session.close()
# Out:
# 2019-12-11 18:23:20,242 INFO sqlalchemy.engine.base.Engine select version()
# 2019-12-11 18:23:20,245 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-11 18:23:20,247 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-12-11 18:23:20,248 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-11 18:23:20,258 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-12-11 18:23:20,261 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-11 18:23:20,266 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-12-11 18:23:20,269 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-11 18:23:20,271 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-12-11 18:23:20,274 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-11 18:23:20,286 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-12-11 18:23:20,289 INFO sqlalchemy.engine.base.Engine {'name': 'Pessoas'}
# 2019-12-11 18:23:20,299 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-12-11 18:23:20,301 INFO sqlalchemy.engine.base.Engine INSERT INTO "Pessoas" (id, username) VALUES (%(id)s, %(username)s)
# 2019-12-11 18:23:20,302 INFO sqlalchemy.engine.base.Engine {'id': 0, 'username': None}
# 2019-12-11 18:23:20,306 INFO sqlalchemy.engine.base.Engine COMMIT
