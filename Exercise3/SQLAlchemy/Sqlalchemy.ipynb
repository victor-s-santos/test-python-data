# %% [markdown]
# # Uma versão do exercício 3 usando o ORM Sqlalchemy.

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install SQLAlchemy
# Out:
# Collecting SQLAlchemy
#   Downloading https://files.pythonhosted.org/packages/34/5c/0e1d7ad0ca52544bb12f9cb8d5cc454af45821c92160ffedd38db0a317f6/SQLAlchemy-1.3.11.tar.gz (6.0MB)
#     100% |████████████████████████████████| 6.0MB 183kB/s ta 0:00:01    35% |███████████▍                    | 2.1MB 1.4MB/s eta 0:00:03
# Installing collected packages: SQLAlchemy
#   Running setup.py install for SQLAlchemy ... done
# Successfully installed SQLAlchemy-1.3.11
# You are using pip version 9.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sqlalchemy import create_engine, Column, String, Integer, Table, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship

Base = declarative_base()

class Books(Base):
    __tablename__ = "books"
    id = Column('id', Integer, primary_key=True)
    key = Column('key', String)
    title = Column('title', String(150))
    published_year = Column('published_year', Integer)
    subjects = relationship("Subject", backref="books")

            
class Subject(Base):        
    __tablename__ = "subjects"
    id = Column('id', Integer, primary_key=True)
    parent_id = Column(Integer, ForeignKey('books.id'))
    subject = Column('subject', String)
    parent = relationship("Books", back_populates="subjects")
    
    
engine = create_engine('postgresql://vsantos93:swordfish@localhost:5432/teste', echo=True)
Base.metadata.create_all(bind=engine)
Session = sessionmaker(bind=engine)
session = Session()
session.commit()
session.close()
# Out:
# 2019-12-14 13:30:29,815 INFO sqlalchemy.engine.base.Engine select version()
# 2019-12-14 13:30:29,817 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-14 13:30:29,822 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-12-14 13:30:29,826 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-14 13:30:29,830 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-12-14 13:30:29,831 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-14 13:30:29,837 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-12-14 13:30:29,839 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-14 13:30:29,840 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-12-14 13:30:29,841 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-14 13:30:29,844 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-12-14 13:30:29,845 INFO sqlalchemy.engine.base.Engine {'name': 'books'}
# 2019-12-14 13:30:29,857 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-12-14 13:30:29,858 INFO sqlalchemy.engine.base.Engine {'name': 'subjects'}
# 2019-12-14 13:30:29,862 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE books (
# 	id SERIAL NOT NULL,
# 	key VARCHAR,
# 	title VARCHAR(150),
# 	published_year INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2019-12-14 13:30:29,863 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-14 13:30:30,010 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-14 13:30:30,034 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE subjects (
# 	id SERIAL NOT NULL,
# 	parent_id INTEGER,
# 	subject VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(parent_id) REFERENCES books (id)
# )
#
#
# 2019-12-14 13:30:30,035 INFO sqlalchemy.engine.base.Engine {}
# 2019-12-14 13:30:30,134 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# Pra fazer a relação many to many entre os livros
# https://www.youtube.com/watch?v=OvhoYbjtiKc
#
# Relação foreignkey
# https://docs.sqlalchemy.org/en/13/orm/basic_relationships.html

# %%
#handling the file
import json
with open('livros_python.json') as arquivo:
    books = json.load(arquivo)
print(type(books))
print(type(books[0]))
print(books[1])
"""I have a dictionary list"""
# Out:
# <class 'list'>
# <class 'dict'>
# {'title_suggest': 'Pythons of Australia', 'edition_key': ['OL707632M'], 'isbn': ['0965744612', '9780965744614'], 'has_fulltext': False, 'text': ['OL707632M', '0965744612', '9780965744614', 'Brian A. Kend', 'Schuett, Laura White.', 'Schuett, Gordon W.', 'OL406588A', 'Pythons of Australia', 'Brian A. Kend ; edited by Gordon W. Schuett and Laura White Schuett.', 'Pythons', '/works/OL2765069W', 'Canyonlands Pub. Group', '97069689', 'Australia'], 'author_name': ['Brian A. Kend'], 'seed': ['/books/OL707632M', '/works/OL2765069W', '/subjects/pythons', '/subjects/place:australia', '/authors/OL406588A'], 'contributor': ['Schuett, Laura White.', 'Schuett, Gordon W.'], 'author_key': ['OL406588A'], 'subject': ['Pythons'], 'title': 'Pythons of Australia', 'publish_date': ['1997'], 'type': 'work', 'ebook_count_i': 0, 'publish_place': ['Provo, Utah'], 'edition_count': 1, 'key': '/works/OL2765069W', 'id_goodreads': ['3813466'], 'publisher': ['Canyonlands Pub. Group'], 'language': ['eng'], 'lccn': ['97069689'], 'last_modified_i': 1280521914, 'id_librarything': ['1301740'], 'publish_year': [1997], 'first_publish_year': 1997, 'place': ['Australia']}
# 'I have a dictionary list'

# %%
#Inserting data from the json file
for id, each_book in enumerate(books):
    key = each_book['key']
    title = each_book['title']
    published_year = (each_book['publish_year'][0])
    subject_list = each_book['subject']
    bookSubject = Subject(subject = subject_list)
    newBook = Books(id = id, key = key, title = title, published_year = published_year)
    newBook.subjects = [bookSubject]
    session.add(newBook)
session.commit()
session.close()
# Out:
# 2019-12-14 13:35:22,858 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-12-14 13:35:22,865 INFO sqlalchemy.engine.base.Engine INSERT INTO books (id, key, title, published_year) VALUES (%(id)s, %(key)s, %(title)s, %(published_year)s)
# 2019-12-14 13:35:22,866 INFO sqlalchemy.engine.base.Engine ({'id': 0, 'key': '/works/OL12266083W', 'title': 'Pythons and their ways', 'published_year': 1930}, {'id': 1, 'key': '/works/OL2765069W', 'title': 'Pythons of Australia', 'published_year': 1997}, {'id': 2, 'key': '/works/OL7551864W', 'title': 'Pythons and their ways', 'published_year': 1930}, {'id': 3, 'key': '/works/OL19543337W', 'title': 'Python Programming: An Introduction to Computer Science, 3rd Ed.', 'published_year': 2016}, {'id': 4, 'key': '/works/OL2913736W', 'title': 'Pythons', 'published_year': 1996}, {'id': 5, 'key': '/works/OL2723583W', 'title': 'Pythons', 'published_year': 2009}, {'id': 6, 'key': '/works/OL2684899W', 'title': 'The first 20 years of Monty Python', 'published_year': 1989}, {'id': 7, 'key': '/works/OL2367908W', 'title': 'Python annotated archives', 'published_year': 1999}  ... displaying 10 of 100 total bound parameter sets ...  {'id': 98, 'key': '/works/OL15909399W', 'title': 'Pythons', 'published_year': 2011}, {'id': 99, 'key': '/works/OL18657847W', 'title': 'The practice of computing using Python', 'published_year': 2010})
# 2019-12-14 13:35:22,910 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,911 INFO sqlalchemy.engine.base.Engine {'parent_id': 0, 'subject': ['Pythons']}
# 2019-12-14 13:35:22,913 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,915 INFO sqlalchemy.engine.base.Engine {'parent_id': 1, 'subject': ['Pythons']}
# 2019-12-14 13:35:22,917 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,918 INFO sqlalchemy.engine.base.Engine {'parent_id': 2, 'subject': ['Pythons']}
# 2019-12-14 13:35:22,920 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,922 INFO sqlalchemy.engine.base.Engine {'parent_id': 3, 'subject': ['Python', 'Python (Computer program language)']}
# 2019-12-14 13:35:22,924 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,929 INFO sqlalchemy.engine.base.Engine {'parent_id': 4, 'subject': ['Juvenile literature', 'Snakes', 'Pythons']}
# 2019-12-14 13:35:22,939 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,940 INFO sqlalchemy.engine.base.Engine {'parent_id': 5, 'subject': ['Pythons as pets']}
# 2019-12-14 13:35:22,942 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,943 INFO sqlalchemy.engine.base.Engine {'parent_id': 6, 'subject': ['Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:22,946 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,947 INFO sqlalchemy.engine.base.Engine {'parent_id': 7, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:22,950 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,952 INFO sqlalchemy.engine.base.Engine {'parent_id': 8, 'subject': ['python', 'biopython', 'bioinformatics']}
# 2019-12-14 13:35:22,956 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,959 INFO sqlalchemy.engine.base.Engine {'parent_id': 9, 'subject': ['Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:22,962 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,963 INFO sqlalchemy.engine.base.Engine {'parent_id': 10, 'subject': ['Python', 'Game Programming']}
# 2019-12-14 13:35:22,966 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,967 INFO sqlalchemy.engine.base.Engine {'parent_id': 11, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:22,969 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,970 INFO sqlalchemy.engine.base.Engine {'parent_id': 12, 'subject': ['Ball pythons as pets']}
# 2019-12-14 13:35:22,972 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,974 INFO sqlalchemy.engine.base.Engine {'parent_id': 13, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:22,976 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,978 INFO sqlalchemy.engine.base.Engine {'parent_id': 14, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:22,980 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,981 INFO sqlalchemy.engine.base.Engine {'parent_id': 15, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:22,984 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,985 INFO sqlalchemy.engine.base.Engine {'parent_id': 16, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:22,989 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,991 INFO sqlalchemy.engine.base.Engine {'parent_id': 17, 'subject': ['Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:22,994 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:22,996 INFO sqlalchemy.engine.base.Engine {'parent_id': 18, 'subject': ['Ball pythons as pets']}
# 2019-12-14 13:35:22,999 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,000 INFO sqlalchemy.engine.base.Engine {'parent_id': 19, 'subject': ['Juvenile literature', 'Pythons']}
# 2019-12-14 13:35:23,002 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,004 INFO sqlalchemy.engine.base.Engine {'parent_id': 20, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,009 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,010 INFO sqlalchemy.engine.base.Engine {'parent_id': 21, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,012 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,013 INFO sqlalchemy.engine.base.Engine {'parent_id': 22, 'subject': ['Juvenile literature', 'Pythons']}
# 2019-12-14 13:35:23,015 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,018 INFO sqlalchemy.engine.base.Engine {'parent_id': 23, 'subject': ['Juvenile literature', 'Pythons']}
# 2019-12-14 13:35:23,021 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,022 INFO sqlalchemy.engine.base.Engine {'parent_id': 24, 'subject': ['Pictorial works', 'Pythons']}
# 2019-12-14 13:35:23,024 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,025 INFO sqlalchemy.engine.base.Engine {'parent_id': 25, 'subject': ['Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:23,027 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,028 INFO sqlalchemy.engine.base.Engine {'parent_id': 26, 'subject': ['Ball pythons as pets']}
# 2019-12-14 13:35:23,038 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,041 INFO sqlalchemy.engine.base.Engine {'parent_id': 27, 'subject': ['Burmese pythons as pets']}
# 2019-12-14 13:35:23,043 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,043 INFO sqlalchemy.engine.base.Engine {'parent_id': 28, 'subject': ['Juvenile literature', 'Pythons']}
# 2019-12-14 13:35:23,045 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,046 INFO sqlalchemy.engine.base.Engine {'parent_id': 29, 'subject': ['Obedience', 'Pythons', 'Fiction']}
# 2019-12-14 13:35:23,048 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,051 INFO sqlalchemy.engine.base.Engine {'parent_id': 30, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,055 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,056 INFO sqlalchemy.engine.base.Engine {'parent_id': 31, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,060 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,060 INFO sqlalchemy.engine.base.Engine {'parent_id': 32, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,062 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,063 INFO sqlalchemy.engine.base.Engine {'parent_id': 33, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,064 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,066 INFO sqlalchemy.engine.base.Engine {'parent_id': 34, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,068 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,068 INFO sqlalchemy.engine.base.Engine {'parent_id': 35, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,072 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,073 INFO sqlalchemy.engine.base.Engine {'parent_id': 36, 'subject': ['Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:23,074 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,075 INFO sqlalchemy.engine.base.Engine {'parent_id': 37, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,077 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,078 INFO sqlalchemy.engine.base.Engine {'parent_id': 38, 'subject': ['Juvenile fiction', 'Pythons', 'Fiction']}
# 2019-12-14 13:35:23,080 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,093 INFO sqlalchemy.engine.base.Engine {'parent_id': 39, 'subject': ['Ball pythons as pets']}
# 2019-12-14 13:35:23,095 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,096 INFO sqlalchemy.engine.base.Engine {'parent_id': 40, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,098 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,098 INFO sqlalchemy.engine.base.Engine {'parent_id': 41, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,100 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,101 INFO sqlalchemy.engine.base.Engine {'parent_id': 42, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,104 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,105 INFO sqlalchemy.engine.base.Engine {'parent_id': 43, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,111 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,112 INFO sqlalchemy.engine.base.Engine {'parent_id': 44, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,114 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,114 INFO sqlalchemy.engine.base.Engine {'parent_id': 45, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,116 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,117 INFO sqlalchemy.engine.base.Engine {'parent_id': 46, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,119 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,120 INFO sqlalchemy.engine.base.Engine {'parent_id': 47, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,122 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,122 INFO sqlalchemy.engine.base.Engine {'parent_id': 48, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,124 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,125 INFO sqlalchemy.engine.base.Engine {'parent_id': 49, 'subject': ['Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:23,126 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,127 INFO sqlalchemy.engine.base.Engine {'parent_id': 50, 'subject': ['Python (Computer program language)']}
# 2019-12-14 13:35:23,129 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,130 INFO sqlalchemy.engine.base.Engine {'parent_id': 51, 'subject': ['Ball pythons as pets']}
# 2019-12-14 13:35:23,131 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,132 INFO sqlalchemy.engine.base.Engine {'parent_id': 52, 'subject': ['Drama', 'Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:23,133 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,134 INFO sqlalchemy.engine.base.Engine {'parent_id': 53, 'subject': ['Python (Langage de programmation)', 'Python (linguagem de programação)', 'In library', 'Python (Computer program language)', 'Python (Lenguaje de pr ... (61 characters truncated) ...  book', 'Python (programmeertaal)', 'Object-oriented programming (Computer science)', 'Python (Computer language)', 'Protected DAISY', 'Interpréteur']}
# 2019-12-14 13:35:23,137 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,138 INFO sqlalchemy.engine.base.Engine {'parent_id': 54, 'subject': ['Computer Technology', 'Python (Computer program language)', 'Accessible book', 'Python (Programmiersprache)', 'Nonfiction', 'Protected DAISY']}
# 2019-12-14 13:35:23,139 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,140 INFO sqlalchemy.engine.base.Engine {'parent_id': 55, 'subject': ['python', 'Python (Computer program language)', 'Accessible book', 'programming', 'Protected DAISY']}
# 2019-12-14 13:35:23,158 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,160 INFO sqlalchemy.engine.base.Engine {'parent_id': 56, 'subject': ['Comedians', 'Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:23,162 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,163 INFO sqlalchemy.engine.base.Engine {'parent_id': 57, 'subject': ['biology', 'Snakes', 'African python', 'boa constrictor', 'anaconda', 'Burmese python', 'reticulated python', 'nonfiction']}
# 2019-12-14 13:35:23,166 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,168 INFO sqlalchemy.engine.base.Engine {'parent_id': 58, 'subject': ['Python (Monty) Pictures', 'Monty Python (Comedy troupe)', 'Censorship']}
# 2019-12-14 13:35:23,171 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,173 INFO sqlalchemy.engine.base.Engine {'parent_id': 59, 'subject': ['Python <Programmiersprache>', 'Verzeichnis', 'Accessible book', 'Python (Programmiersprache)', 'Protected DAISY', 'Befehlsvorrat']}
# 2019-12-14 13:35:23,177 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,179 INFO sqlalchemy.engine.base.Engine {'parent_id': 60, 'subject': ['Python 3', 'Computing', 'Python', 'Accessible book', 'Programming languages', 'Initiation', 'Technology']}
# 2019-12-14 13:35:23,181 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,183 INFO sqlalchemy.engine.base.Engine {'parent_id': 61, 'subject': ['Python 3', 'Computing', 'Python', 'Accessible book', 'Programming languages', 'Initiation']}
# 2019-12-14 13:35:23,185 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,187 INFO sqlalchemy.engine.base.Engine {'parent_id': 62, 'subject': ['Python <Programmiersprache>', 'Python', '(Programmiersprache)', 'Accessible book', 'Protected DAISY']}
# 2019-12-14 13:35:23,189 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,190 INFO sqlalchemy.engine.base.Engine {'parent_id': 63, 'subject': ['Accessible book', 'Python (Programmiersprache)', 'Python 3.0.', 'Protected DAISY']}
# 2019-12-14 13:35:23,193 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,194 INFO sqlalchemy.engine.base.Engine {'parent_id': 64, 'subject': ['Python 3.0', 'Accessible book', 'Python 3.0.', 'Protected DAISY']}
# 2019-12-14 13:35:23,196 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,197 INFO sqlalchemy.engine.base.Engine {'parent_id': 65, 'subject': ['Introduced reptiles', 'Python (Genus)', 'Burmese python', 'Internet Archive Wishlist']}
# 2019-12-14 13:35:23,199 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,200 INFO sqlalchemy.engine.base.Engine {'parent_id': 66, 'subject': ['Pythons -- Fiction.', 'Jungle animals -- Fiction.']}
# 2019-12-14 13:35:23,203 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,205 INFO sqlalchemy.engine.base.Engine {'parent_id': 67, 'subject': ['Drama', 'Monty Python (Comedy troupe)']}
# 2019-12-14 13:35:23,207 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,208 INFO sqlalchemy.engine.base.Engine {'parent_id': 68, 'subject': ['Python (Computer program language)', 'Bioinformatics']}
# 2019-12-14 13:35:23,210 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,212 INFO sqlalchemy.engine.base.Engine {'parent_id': 69, 'subject': ['Python (Computer program language)', 'Bioinformatics']}
# 2019-12-14 13:35:23,214 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,237 INFO sqlalchemy.engine.base.Engine {'parent_id': 70, 'subject': ['Law and legislation', 'Pythons', 'Boidae']}
# 2019-12-14 13:35:23,241 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,243 INFO sqlalchemy.engine.base.Engine {'parent_id': 71, 'subject': ['Juvenile fiction', 'Mice', 'Pythons', 'Elephants']}
# 2019-12-14 13:35:23,246 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,247 INFO sqlalchemy.engine.base.Engine {'parent_id': 72, 'subject': ['Python (Computer program language)', 'Microcontrollers']}
# 2019-12-14 13:35:23,250 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,251 INFO sqlalchemy.engine.base.Engine {'parent_id': 73, 'subject': ['In library', 'Accessible book', 'Anaconda', 'African rock python', 'Protected DAISY', 'Indian python', 'Reticulated python']}
# 2019-12-14 13:35:23,254 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,255 INFO sqlalchemy.engine.base.Engine {'parent_id': 74, 'subject': ["Monty Python's Flying Circus (Television program)", 'Television', 'Monty Python (Comedy troupe)', 'Censorship']}
# 2019-12-14 13:35:23,258 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,259 INFO sqlalchemy.engine.base.Engine {'parent_id': 75, 'subject': ['Python (programmeertaal)', 'In library', 'Python (Computer program language)', 'Accessible book', 'Protected DAISY']}
# 2019-12-14 13:35:23,261 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,262 INFO sqlalchemy.engine.base.Engine {'parent_id': 76, 'subject': ['Multimedia systems', 'Python (Computer program language)']}
# 2019-12-14 13:35:23,269 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,271 INFO sqlalchemy.engine.base.Engine {'parent_id': 77, 'subject': ["Monty Python's Flying Circus (Television program)"]}
# 2019-12-14 13:35:23,276 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,277 INFO sqlalchemy.engine.base.Engine {'parent_id': 78, 'subject': ['Snakes as pets', 'Pets', 'Pythons', 'Fiction']}
# 2019-12-14 13:35:23,280 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,282 INFO sqlalchemy.engine.base.Engine {'parent_id': 79, 'subject': ['In library', 'Python (Computer program language)', 'Accessible book', 'Protected DAISY']}
# 2019-12-14 13:35:23,284 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,286 INFO sqlalchemy.engine.base.Engine {'parent_id': 80, 'subject': ['Accessible book', 'Python (Computer program language)', 'Protected DAISY']}
# 2019-12-14 13:35:23,288 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,289 INFO sqlalchemy.engine.base.Engine {'parent_id': 81, 'subject': ['In library', 'Snakes', 'Accessible book', 'Protected DAISY', 'Indian python', 'Juvenile literature', 'Pythons']}
# 2019-12-14 13:35:23,291 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,293 INFO sqlalchemy.engine.base.Engine {'parent_id': 82, 'subject': ['Python (Monty) Pictures', 'In library', 'Accessible book', 'Monty Python (Comedy troupe)', "Monty Python's Flying Circus (Television program)", 'Comedians', 'Protected DAISY', 'Biography']}
# 2019-12-14 13:35:23,295 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,296 INFO sqlalchemy.engine.base.Engine {'parent_id': 83, 'subject': ['Pythons', 'Humorous stories', 'Snakes', 'Family life', 'Fiction']}
# 2019-12-14 13:35:23,298 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,299 INFO sqlalchemy.engine.base.Engine {'parent_id': 84, 'subject': ['Anatomy', 'Pelvic bones', 'Embryology', 'Reticulated python']}
# 2019-12-14 13:35:23,311 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,313 INFO sqlalchemy.engine.base.Engine {'parent_id': 85, 'subject': ['Computer programming', 'Python (Computer program language)']}
# 2019-12-14 13:35:23,316 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,317 INFO sqlalchemy.engine.base.Engine {'parent_id': 86, 'subject': ['Boidae', 'Juvenile literature', 'Boa constrictor', 'Pythons', 'Snakes']}
# 2019-12-14 13:35:23,319 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,321 INFO sqlalchemy.engine.base.Engine {'parent_id': 87, 'subject': ['Computer programming', 'Python (Computer program language)']}
# 2019-12-14 13:35:23,327 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,328 INFO sqlalchemy.engine.base.Engine {'parent_id': 88, 'subject': ['Python (Computer program language)', 'Microsoft Win32']}
# 2019-12-14 13:35:23,331 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,332 INFO sqlalchemy.engine.base.Engine {'parent_id': 89, 'subject': ['Stories in rhyme', 'Snakes', 'Pythons', 'Fiction']}
# 2019-12-14 13:35:23,334 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,336 INFO sqlalchemy.engine.base.Engine {'parent_id': 90, 'subject': ["Monty Python's complete waste of time"]}
# 2019-12-14 13:35:23,344 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,345 INFO sqlalchemy.engine.base.Engine {'parent_id': 91, 'subject': ['Reproduction', 'Breeding', 'Snake culture', 'Pythons', 'Boidae']}
# 2019-12-14 13:35:23,347 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,349 INFO sqlalchemy.engine.base.Engine {'parent_id': 92, 'subject': ['Python (Computer program language)', 'Microsoft Win32']}
# 2019-12-14 13:35:23,351 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,352 INFO sqlalchemy.engine.base.Engine {'parent_id': 93, 'subject': ['Ball pythons as pets', 'Juvenile literature']}
# 2019-12-14 13:35:23,359 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,361 INFO sqlalchemy.engine.base.Engine {'parent_id': 94, 'subject': ['Multimedia systems', 'Python (Computer program language)']}
# 2019-12-14 13:35:23,363 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,365 INFO sqlalchemy.engine.base.Engine {'parent_id': 95, 'subject': ['Python (Computer program language)', 'Programming', 'Computer games']}
# 2019-12-14 13:35:23,367 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,369 INFO sqlalchemy.engine.base.Engine {'parent_id': 96, 'subject': ['Juvenile literature', 'Pythons', 'Internet Archive Wishlist']}
# 2019-12-14 13:35:23,372 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,373 INFO sqlalchemy.engine.base.Engine {'parent_id': 97, 'subject': ['Ball pythons as pets', 'Internet Archive Wishlist']}
# 2019-12-14 13:35:23,375 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,382 INFO sqlalchemy.engine.base.Engine {'parent_id': 98, 'subject': ['Juvenile literature', 'Pythons', 'Internet Archive Wishlist']}
# 2019-12-14 13:35:23,384 INFO sqlalchemy.engine.base.Engine INSERT INTO subjects (parent_id, subject) VALUES (%(parent_id)s, %(subject)s) RETURNING subjects.id
# 2019-12-14 13:35:23,387 INFO sqlalchemy.engine.base.Engine {'parent_id': 99, 'subject': ['Computer programming', 'Python (Computer program language)']}
# 2019-12-14 13:35:23,399 INFO sqlalchemy.engine.base.Engine COMMIT
